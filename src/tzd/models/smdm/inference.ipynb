# %%
# !wget https://huggingface.co/nieshen/SMDM/resolve/main/mdm_safetensors/mdm-113M-30e18.safetensors

# %%
# Out:
# Ramith: cannot use FusedRMSNorm. following litgpt
# Ramith: cannot use FusedRMSNorm. following litgpt
# Ramith: cannot use FusedRMSNorm. following litgpt
# Ramith: cannot use FusedRMSNorm. following litgpt
# Ramith: cannot use FusedRMSNorm. following litgpt
# Ramith: cannot use FusedRMSNorm. following litgpt
# Ramith: cannot use FusedRMSNorm. following litgpt
# Ramith: cannot use FusedRMSNorm. following litgpt
# Ramith: cannot use FusedRMSNorm. following litgpt
# Ramith: cannot use FusedRMSNorm. following litgpt
# Ramith: cannot use FusedRMSNorm. following litgpt
# Ramith: cannot use FusedRMSNorm. following litgpt
# Ramith: cannot use FusedRMSNorm. following litgpt
# Ramith: cannot use FusedRMSNorm. following litgpt
# Ramith: cannot use FusedRMSNorm. following litgpt
# Ramith: cannot use FusedRMSNorm. following litgpt
# Ramith: cannot use FusedRMSNorm. following litgpt
# Ramith: cannot use FusedRMSNorm. following litgpt
# Ramith: cannot use FusedRMSNorm. following litgpt
# ...
